# %% [markdown]
# <a href="https://colab.research.google.com/github/dscho15/Convex-Optimization/blob/main/Lec2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sympy as sym
from sympy.plotting.plot import Plot, ContourSeries
sym.init_printing()
# https://www.youtube.com/watch?v=Zxe2z5SrkHI

# %%
x1 = sym.Symbol('x1')
x2 = sym.Symbol('x2')

f = 100*(x2-x1**2)**2 +(1-x1)**2

grad_f = [f.diff(x) for x in [x1, x2]]

hess_f = [grad_f for x in [x1, x2]]

# %%
print("Gradient \n")
grad_f
# Out:
# Gradient
# ⎡         ⎛    2     ⎞                     2         ⎤
# ⎣- 400⋅x₁⋅⎝- x₁  + x₂⎠ + 2⋅x₁ - 2, - 200⋅x₁  + 200⋅x₂⎦

# %%
print("Hessian \n")
hess_f
# Out:
# Hessian
# ⎡⎡         ⎛    2     ⎞                     2         ⎤  ⎡         ⎛    2
# ⎣⎣- 400⋅x₁⋅⎝- x₁  + x₂⎠ + 2⋅x₁ - 2, - 200⋅x₁  + 200⋅x₂⎦, ⎣- 400⋅x₁⋅⎝- x₁  + x₂
#
# ⎞                     2         ⎤⎤
# ⎠ + 2⋅x₁ - 2, - 200⋅x₁  + 200⋅x₂⎦⎦

# %%
plt.plot3d(f, (x1, -2, 2), (x2, -2, 2), size=(15, 15))

# %%
x1 = sym.Symbol('x1')
x2 = sym.Symbol('x2')

f = 8*x1 + 12*x2 + x1**2 - 2*x2**2

grad_f = [f.diff(x) for x in [x1, x2]]

grad_f
# Out:
# [2⋅x₁ + 8, 12 - 4⋅x₂]

# %%
plt = Plot(ContourSeries(f, (x1, -6, -2), (x2, 1, 5)))
plt.show()
